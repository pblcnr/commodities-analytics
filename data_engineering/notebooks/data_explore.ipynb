# %%
import pandas as pd

# %%
df = pd.read_csv('../data/PrecoMensalMun.csv', sep=';', decimal=',', encoding='latin-1')
df.columns
# Out:
# Index(['produto', 'classificao_produto', 'id_produto', 'nom_municipio',
#        'cod_ibge', 'uf', 'regiao', 'ano', 'mes', 'dsc_nivel_comercializacao',
#        'valor_produto_kg'],
#       dtype='str')
